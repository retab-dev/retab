# %% [markdown]
# # **MANUFACTURERS—AUTO PACKAGE INGESTION**

# %% [markdown]
# This Notebook leverages the **Processors** configured on **[Retab](https://www.retab.com/)** to process Auto Manufacturer's Package (like Audi, CNH, Bridgestone, etc.) with high accuracy and reliability, based on an extraction schema defined and optimized on the platform.
#
# These Packages include various documents:
# - Retail/Lease (apps, payslips, IDs, etc.)
# - Income/KYC
# - Dealer incentive
# - Warranty claim reconciliation
# - Many more
#
# *Retab's platform enables to automatically generale - iterate - deploy your schemas & prompts into production. See the [Documentation here](https://docs.retab.com/overview/introduction)*
#
# Built with 🩷 by Retab.

# %% [markdown]
# We recommmend to initiate your **Retab API Key** on **[Retab](https://www.retab.com/)** and save them in a `.env` file.
#
# You should have:
# ```
# RETAB_API_KEY=sk_retab_***

# %%
# INITIALIZATION

from dotenv import load_dotenv
from retab import Retab

load_dotenv() # Import the Retab API key from the .env file

client = Retab()

# %%
# PARAMETERS

# ---- Classifier -> leverage Retab to classify the documents for Auto Manufacturers
CLASSIFIER_PROJECT_ID = "proj_NzodKxtfWqB5oFuvZrlAP"
CLASSIFIER_ITERATION_ID = "base-configuration"

# ---- Routing map (Extraction projects) -> re-route the classified documents 
# to the corresponding extractors configured on Retab to process them with the right schema
DEST_PROJECTS = {
    "certificate_of_origin": {
        "project_id":   "proj_1j0RaQySBc_nwmD5lI4Ld",
        "iteration_id": "eval_iter_azDPRn5mEjnMdZ_4CThAS",
    },
    "driver_license": {
        "project_id":   "proj_va3ZR5HLHjrfjGwryTY1R",      
        "iteration_id": "eval_iter_omPLcS69TmzSw-pQZKF2c",
    },
    # We can add more as we wire them on the platform
    # Not wired yet: "KYC", "DEALER_INCENTIVE", "WARRANTY_CLAIM_RECONCILIATION", "OTHER"
}

# Map raw classifier labels with the routing keys above
CATEGORY_TO_KEY = {
    "CERTIFICATE_OF_ORIGIN":   "certificate_of_origin",
    "IDENTIFICATION_DOCUMENT": "driver_license",
}

# %%
# PROCESS WITH RETAB

from pathlib import Path
import re

DIR = "../assets/docs/Manufacturers/" # Sample documents foudn on the Web

EXTS = {".pdf", ".png", ".jpg", ".jpeg", ".webp"} # You can add more if needed

for doc in Path(DIR).glob("*"):
    if doc.suffix.lower() not in EXTS:
        continue

    print(f"\nProcessing: {doc.name}")

    # --- Classify with Retab
    clf_res = client.projects.extract(
        project_id=CLASSIFIER_PROJECT_ID,
        iteration_id=CLASSIFIER_ITERATION_ID,
        document=str(doc),
    )

    # --- Inline label read
    out = getattr(clf_res, "output", {}) or {}
    label = None
    for k in ("doc_type", "DOCUMENT_TYPE", "document_type", "label", "class", "category", "type"):
        v = out.get(k)
        if v:
            label = str(v).strip().upper()
            break
        if not label:
            m = re.search(
                r'"(?:doc[_\s-]?type|DOCUMENT[_\s-]?TYPE|document[_\s-]?type|label|class|category|type)"\s*:\s*"([^"]+)"',
                str(clf_res),
                flags=re.I,
            )
            if m:
                label = m.group(1).strip().upper()

    print(f"Classifier → {label!r}")

    # --- Route
    route_key = CATEGORY_TO_KEY.get(label)
    if not route_key:
        print(f"No route for {label}, skipping.")
        continue

    dest = DEST_PROJECTS[route_key]

    # --- Extract with Retab
    extraction = client.projects.extract(
        project_id=dest["project_id"],
        iteration_id=dest["iteration_id"],
        document=str(doc),
    )

    print(f"Extraction result → {extraction}")
# Out:
# Processing: risc_sample5.webp
# Classifier → 'CONTRACT'
# No route for CONTRACT, skipping.
#
# Processing: certificate_of_origin_sample1.png
# Classifier → 'CERTIFICATE_OF_ORIGIN'
# Extraction result → RetabParsedChatCompletion(id='NPKiaP6TEIW7xN8PhOGYsAE', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"issue_date": "2003-10-29", "certificate_number": "RBLPD019", "document_title": "CERTIFICATE OF ORIGIN FOR A VEHICLE", "manufacturer": {"name": "CHEVROLET MOTOR DIVISION GENERAL MOTORS CORPORATION", "brand": "CHEVROLET", "address_line": "null", "city": "DETROIT", "state_province": "MI", "country": "null"}, "vehicle": {"vin": "1GCEK19T34E191229", "year": 2004, "make": "CHEVROLET", "model": "null", "body_type": "PICKUP", "series_or_trim": "CK15753", "engine_power_hp": 44, "engine_displacement_cc": 0, "gvwr_lbs": 6400, "shipping_weight_lbs": 4957, "cylinders": 8, "drive_type": "null", "fuel_type": "null", "color": "null"}, "emissions_and_certification": {"sale_certification_scope": "certified_for_sale_in_all_states", "conformity_statement_present": true, "emission_system": "50-STATE EMISSION SYSTEM"}, "dealer": {"name": "MOORE CHEVROLET, INC.", "dealer_number": "08438 GRQP4F", "address_line": "PO BOX 100", "city": "BARNESVILLE", "state_province": "GA", "postal_code": "30204-0100"}, "mail_to": {"name": "null", "address_line": "null", "city": "null", "state_province": "null", "postal_code": "null"}, "transfer_statement": {"first_transfer_certified": true, "duplicate_indicator": false, "duplicate_reason_text": "null", "authorized_representative_name": "null", "authorized_representative_signature_present": true, "signature_date": "null", "issuing_location_city": "DETROIT", "issuing_location_state": "MI"}}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'issue_date': '2003-10-29', 'certificate_number': 'RBLPD019', 'document_title': 'CERTIFICATE OF ORIGIN FOR A VEHICLE', 'manufacturer': {'name': 'CHEVROLET MOTOR DIVISION GENERAL MOTORS CORPORATION', 'brand': 'CHEVROLET', 'address_line': 'null', 'city': 'DETROIT', 'state_province': 'MI', 'country': 'null'}, 'vehicle': {'vin': '1GCEK19T34E191229', 'year': 2004, 'make': 'CHEVROLET', 'model': 'null', 'body_type': 'PICKUP', 'series_or_trim': 'CK15753', 'engine_power_hp': 44, 'engine_displacement_cc': 0, 'gvwr_lbs': 6400, 'shipping_weight_lbs': 4957, 'cylinders': 8, 'drive_type': 'null', 'fuel_type': 'null', 'color': 'null'}, 'emissions_and_certification': {'sale_certification_scope': 'certified_for_sale_in_all_states', 'conformity_statement_present': True, 'emission_system': '50-STATE EMISSION SYSTEM'}, 'dealer': {'name': 'MOORE CHEVROLET, INC.', 'dealer_number': '08438 GRQP4F', 'address_line': 'PO BOX 100', 'city': 'BARNESVILLE', 'state_province': 'GA', 'postal_code': '30204-0100'}, 'mail_to': {'name': 'null', 'address_line': 'null', 'city': 'null', 'state_province': 'null', 'postal_code': 'null'}, 'transfer_statement': {'first_transfer_certified': True, 'duplicate_indicator': False, 'duplicate_reason_text': 'null', 'authorized_representative_name': 'null', 'authorized_representative_signature_present': True, 'signature_date': 'null', 'issuing_location_city': 'DETROIT', 'issuing_location_state': 'MI'}}), field_locations=None, key_mapping=None), RetabParsedChoice(finish_reason='stop', index=1, logprobs=None, message=ParsedChatCompletionMessage(content='{"document_title": "CERTIFICATE OF ORIGIN FOR A VEHICLE", "issue_date": "2003-10-29", "certificate_number": "RBLPD019", "manufacturer": {"name": "CHEVROLET MOTOR DIVISION GENERAL MOTORS CORPORATION", "brand": "CHEVROLET", "address_line": "null", "city": "DETROIT", "state_province": "MI", "country": "null"}, "vehicle": {"vin": "1GCEK19T34E191229", "year": 2004, "make": "CHEVROLET", "model": "CK15753", "body_type": "PICKUP", "series_or_trim": "CK15753", "engine_power_hp": 44, "engine_displacement_cc": 0, "gvwr_lbs": 6400, "shipping_weight_lbs": 4957, "cylinders": 8, "drive_type": "null", "fuel_type": "null", "color": "null"}, "emissions_and_certification": {"sale_certification_scope": "certifi ...
#
# Processing: certificate_of_origin_sample2 (bad quality).jpeg
# Classifier → 'CERTIFICATE_OF_ORIGIN'
# Extraction result → RetabParsedChatCompletion(id='JjOkaJ3ZMuzTvdIPyJPMuA8', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"issue_date": "2003-09-16", "certificate_number": "4DR165810925", "document_title": "CERTIFICATE OF ORIGIN FOR A VEHICLE", "manufacturer": {"name": "DaimlerChrysler Motors Company LLC", "brand": "DODGE", "address_line": "", "city": "", "country": "", "state_province": ""}, "vehicle": {"vin": "1D7HA18DX4S551016", "year": 2004, "make": "DODGE", "model": "RAM DR1H41", "body_type": "1500 QUAD CAB PICKUP", "series_or_trim": "RAM DR1H41", "engine_power_hp": 49, "engine_displacement_cc": 0, "gvwr_lbs": 6650, "shipping_weight_lbs": 4828, "cylinders": 8, "color": "", "drive_type": "", "fuel_type": ""}, "emissions_and_certification": {"sale_certification_scope": "certified_for_sale_in_all_states", "conformity_statement_present": true, "emission_system": ""}, "dealer": {"name": "BILL PIERRE DODGE INC", "dealer_number": "42705/42705", "address_line": "PO BOX 27165", "city": "SEATTLE", "state_province": "WA", "postal_code": "98125"}, "mail_to": {"name": "BILL PIERRE DODGE INC", "address_line": "PO BOX 27165", "city": "SEATTLE", "state_province": "WA", "postal_code": "98125"}, "transfer_statement": {"first_transfer_certified": true, "duplicate_indicator": true, "duplicate_reason_text": "THE ORIGINAL CERTIFICATE DATED 09/16/03 HAS BEEN REPORTED LOST; THIS DUPLICATE IS ISSUED ON 08/31/04.", "authorized_representative_signature_present": true, "signature_date": "2004-08-31", "issuing_location_city": "AUBURN HILLS", "issuing_location_state": "MICHIGAN", "authorized_representative_name": ""}}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'issue_date': '2003-09-16', 'certificate_number': '4DR165810925', 'document_title': 'CERTIFICATE OF ORIGIN FOR A VEHICLE', 'manufacturer': {'name': 'DaimlerChrysler Motors Company LLC', 'brand': 'DODGE', 'address_line': '', 'city': '', 'country': '', 'state_province': ''}, 'vehicle': {'vin': '1D7HA18DX4S551016', 'year': 2004, 'make': 'DODGE', 'model': 'RAM DR1H41', 'body_type': '1500 QUAD CAB PICKUP', 'series_or_trim': 'RAM DR1H41', 'engine_power_hp': 49, 'engine_displacement_cc': 0, 'gvwr_lbs': 6650, 'shipping_weight_lbs': 4828, 'cylinders': 8, 'color': '', 'drive_type': '', 'fuel_type': ''}, 'emissions_and_certification': {'sale_certification_scope': 'certified_for_sale_in_all_states', 'conformity_statement_present': True, 'emission_system': ''}, 'dealer': {'name': 'BILL PIERRE DODGE INC', 'dealer_number': '42705/42705', 'address_line': 'PO BOX 27165', 'city': 'SEATTLE', 'state_province': 'WA', 'postal_code': '98125'}, 'mail_to': {'name': 'BILL PIERRE DODGE INC', 'address_line': 'PO BOX 27165', 'city': 'SEATTLE', 'state_province': 'WA', 'postal_code': '98125'}, 'transfer_statement': {'first_transfer_certified': True, 'duplicate_indicator': True, 'duplicate_reason_text': 'THE ORIGINAL CERTIFICATE DATED 09/16/03 HAS BEEN REPORTED LOST; THIS DUPLICATE IS ISSUED ON 08/31/04.', 'authorized_representative_signature_present': True, 'signature_date': '2004-08-31', 'issuing_location_city': 'AUBURN HILLS', 'issuing_location_state': 'MICHIGAN', 'authorized_representative_name': ''}}), field_locations=None, key_mapping=None), RetabParsedChoice(finish_reason='stop', index=1, logprobs=None, message=ParsedChatCompletionMessage(content='{"document_title": "CERTIFICATE OF ORIGIN FOR A VEHICLE", "issue_date": "2003-09-16", "certificate_number": "4DR165810925", "manufacturer": {"name": "DaimlerChrysler Motors Company LLC", "brand": "DAIMLERCHRYSLER", "address_line": "", "city": "AUBURN HILLS", "state_province": "MICHIGAN", "country": ""}, "vehicle": {"vin": "1D7HA18DX4S551016", "year": 2004, "make": "DODGE", "model": "RAM DR1H41", "body_type": "1500 QUAD CAB PICKUP", "series_or_trim": "RAM DR1H41", "engine_power_hp": 49, "engine_displacement_cc": 0, "gvwr_lbs": 6650, "shippin ...
#
# Processing: drivers_licence_sample5.png
# Classifier → 'IDENTIFICATION_DOCUMENT'
# Extraction result → RetabParsedChatCompletion(id='J_KiaKiROfO6xN8Pz_akyA4', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"jurisdiction": "DC", "license_class": "A", "license_number": "A9999999", "issue_date": "2010-02-17", "expiry_date": "2018-02-21", "full_name": "ANGELINA GABRIELA JONES", "last_name": "JONES", "first_name": "ANGELINA GABRIELA", "date_of_birth": "1984-02-21", "sex": "female", "eye_color": "bro", "hair_color": "oth", "organ_donor": true, "veteran_status": true, "restrictions": "3", "endorsements": "NONE", "height_in_inches": 62, "photo_present": true, "weight_in_pounds": 120, "document_number": "12348757475974", "compliance": "real_id", "address": {"street": "1234 COMMODORE JOSHUA BARNEY DRIVE, NE", "street_2": "#1234", "city": "WASHINGTON", "state": "DC", "postal_code": "00000-0000"}}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'jurisdiction': 'DC', 'license_class': 'A', 'license_number': 'A9999999', 'issue_date': '2010-02-17', 'expiry_date': '2018-02-21', 'full_name': 'ANGELINA GABRIELA JONES', 'last_name': 'JONES', 'first_name': 'ANGELINA GABRIELA', 'date_of_birth': '1984-02-21', 'sex': 'female', 'eye_color': 'bro', 'hair_color': 'oth', 'organ_donor': True, 'veteran_status': True, 'restrictions': '3', 'endorsements': 'NONE', 'height_in_inches': 62, 'photo_present': True, 'weight_in_pounds': 120, 'document_number': '12348757475974', 'compliance': 'real_id', 'address': {'street': '1234 COMMODORE JOSHUA BARNEY DRIVE, NE', 'street_2': '#1234', 'city': 'WASHINGTON', 'state': 'DC', 'postal_code': '00000-0000'}}), field_locations=None, key_mapping=None), RetabParsedChoice(finish_reason='stop', index=1, logprobs=None, message=ParsedChatCompletionMessage(content='{"jurisdiction": "DC", "license_class": "A", "license_number": "A9999999", "issue_date": "2010-02-17", "expiry_date": "2018-02-21", "full_name": "ANGELINA GABRIELA JONES", "last_name": "JONES", "first_name": "ANGELINA GABRIELA", "date_of_birth": "1984-02-21", "sex": "female", "height_in_inches": 62, "reasoning___weight_in_pounds": "Extracted \'120\' from the \'17.WGT\' field in the Driver Attributes table. The value is explicitly given.", "weight_in_pounds": 120, "eye_color": "bro", "hair_color": "bro", "organ_donor": true, "veteran_status": true, "restrictions": "3", "endorsements": "NONE", "address": {"street": "1234 COMMODORE JOSHUA BARNEY DRIVE, NE", "reasoning___street_2": "Extracted \'#1234\' from the address block, which appears as a secondary address line following the primary street address.", "street_2": "#1234", "city": "WASHINGTON", "state": "DC", "postal_code": "00000-0000"}, "photo_present": true, "reasoning___document_number": "Extracted \'12348757475974\' from the \'5.DD\' field. This is a common location for an additional document identifier on driver licenses. The vertical ID number \'999999999 02211984\' was considered but rejected as the primary document number due to its composite nature (including DOB) and the presence of the more conventionally formatted \'5.DD\' field.", "document_number": "12348757475974", "compliance": "real_id"}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'jurisdiction': 'DC', 'license_class': 'A', 'license_number': 'A9999999', 'issue_date': '2010-02-17', 'expiry_date': '2018-02-21', 'full_name': 'ANGELINA GABRIELA JONES', 'last_name': 'JONES', 'first_name': 'ANGELINA GABRIELA', 'date_of_birth': '1984-02-21', 'sex': 'female', 'height_in_inches': 62, 'reasoning___weight_in_pounds': "Extracted '120' from the '17.WGT' field in the Driver Attributes table. The value is explicitly given.", 'weight_in_pounds': 120, 'eye_color': 'bro', 'hair_color': 'bro', 'organ_donor': True, 'veteran_status': True, 'restrictions': '3', 'endorsements': 'NONE', 'address': {'street': '1234 COMMODORE JOSHUA BARNEY DRIVE, NE', 'reasoning___ ...
#
# Processing: warranty_booklet_sample4.pdf
# Classifier → 'OTHER'
# No route for OTHER, skipping.

# %%
# PRINT THE EXTRACTION RESULT IN A NICE JSON FORMAT

import json

parsed_data = json.loads(extraction.choices[0].message.content)
formatted_json = json.dumps(parsed_data, indent=2, ensure_ascii=False)

print(formatted_json)
# Out:
# {
#   "jurisdiction": "DC",
#   "license_class": "A",
#   "license_number": "A9999999",
#   "issue_date": "2010-02-17",
#   "expiry_date": "2018-02-21",
#   "full_name": "ANGELINA GABRIELA JONES",
#   "last_name": "JONES",
#   "first_name": "ANGELINA GABRIELA",
#   "date_of_birth": "1984-02-21",
#   "sex": "female",
#   "eye_color": "bro",
#   "hair_color": "oth",
#   "organ_donor": true,
#   "veteran_status": true,
#   "restrictions": "3",
#   "endorsements": "NONE",
#   "height_in_inches": 62,
#   "photo_present": true,
#   "weight_in_pounds": 120,
#   "document_number": "12348757475974",
#   "compliance": "real_id",
#   "address": {
#     "street": "1234 COMMODORE JOSHUA BARNEY DRIVE, NE",
#     "street_2": "#1234",
#     "city": "WASHINGTON",
#     "state": "DC",
#     "postal_code": "00000-0000"
#   }
# }
