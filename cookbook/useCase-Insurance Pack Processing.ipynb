# %% [markdown]
# # **STATE FARM INSURANCE—CLAIMS BILLING PACKAGE INGESTION**

# %% [markdown]
# This Notebook leverages the **Processors** configured on **[Retab](https://www.retab.com/)** to process the Claims Billing Package of the State Farm Insurance with high accuracy and reliability, based on an extraction schema defined and optimized on the platform.
#
# These Packages include various documents:
# - Claim billings (estimates, medical bills, invoices, etc.) with CPT/HCPCS/parts codes
# - Loss-run generations
# - Subrogation recovery
# - Legal demand letters
# - Coverage opinions
# - Litigation packages
# - Many more
#
# *Retab's platform enables to automatically generale - iterate - deploy your schemas & prompts into production. See the [Documentation here](https://docs.retab.com/overview/introduction)*
#
# Built with 🩷 by Retab.

# %% [markdown]
# We recommmend to initiate your **Retab API Key** on **[Retab](https://www.retab.com/)** and save them in a `.env` file.
#
# You should have:
# ```
# RETAB_API_KEY=sk_retab_***

# %%
# INITIALIZATION

from dotenv import load_dotenv
from retab import Retab

load_dotenv() # Import the Retab API key from the .env file

client = Retab()

# %%
# PARAMETERS

# ---- Classifier -> leverage Retab to classify the documents of Claims Billing Package
CLASSIFIER_PROJECT_ID = "proj_Wdr_IVbaGq0mFxiCLHdSY"
CLASSIFIER_ITERATION_ID = "base-configuration"

# ---- Routing map (Extraction projects) -> re-route the classified documents 
# to the corresponding extractors configured on Retab to process them with the right schema
DEST_PROJECTS = {
    "repair_estimate": {
        "project_id":   "proj_gZtHZWuTtAxi_xOqOIXrJ",
        "iteration_id": "eval_iter_o-t8_4X3uJEYeF8-4DJLV",
    },
    "medical_bill": {
        "project_id":   "proj_kJ-sHsVP6_UQQVCGOArmk",         # both CMS1500 and UB04
        "iteration_id": "eval_iter_VBk_n-SOk-9HOaxulyMDb",
    },
    "contractor_invoice": {
        "project_id":   "proj_XxbzN5ymYJn3KMT6vzgRw",
        "iteration_id": "eval_iter_3V1XNKzHkYiUUVW5JzNVD",
    },
    "demand_letter": {
        "project_id":   "proj_ijmWRdVglm6C_ORTIoqpr",
        "iteration_id": "eval_iter_et1oJq0ZJ7xp21PB5UadK",
    },
    "loss_run": {
        "project_id":   "proj_W17iPKczi0pEZhFsQk0um",
        "iteration_id": "eval_iter_Tvu9aBwHMAPeHRqDEZywm",
    },
    # We can add more as we wire them on the platform
    # Not wired yet: "COVERAGE_POSITION", "EOB", "POLICE_REPORT",
    # "PROOF_OF_LOSS", "POLICY_DECLARATIONS", "PHOTO_EVIDENCE", "OTHER"
}

# Map raw classifier labels with the routing keys above
CATEGORY_TO_KEY = {
    "REPAIR_ESTIMATE":       "repair_estimate",
    "MEDICAL_BILL_CMS1500":  "medical_bill",
    "MEDICAL_BILL_UB04":     "medical_bill",
    "CONTRACTOR_INVOICE":    "contractor_invoice",
    "DEMAND_LETTER":         "demand_letter",
    "LOSS_RUN":              "loss_run",
}

# %%
# PROCESS WITH RETAB

from pathlib import Path
import re

DIR = "../assets/docs/Insurance-StateFarm/" # Sample documents foudn on the Web

EXTS = {".pdf", ".png", ".jpg", ".jpeg", ".webp"} # You can add more if needed

for doc in Path(DIR).glob("*"):
    if doc.suffix.lower() not in EXTS:
        continue

    print(f"\nProcessing: {doc.name}")

    # --- Classify with Retab
    clf_res = client.projects.extract(
        project_id=CLASSIFIER_PROJECT_ID,
        iteration_id=CLASSIFIER_ITERATION_ID,
        document=str(doc),
    )

    # --- Inline label read
    out = getattr(clf_res, "output", None)
    label = None
    if isinstance(out, dict):
        label = out.get("DOCUMENT_TYPE") or out.get("document_type")
    if not label:
        m = re.search(r'"(?:DOCUMENT_TYPE|document_type)"\s*:\s*"([^"]+)"', str(clf_res))
        if m:
            label = m.group(1)
    label = label.strip().upper() if isinstance(label, str) else None

    print(f"Classifier → {label!r}")

    # --- Route
    route_key = CATEGORY_TO_KEY.get(label)
    if not route_key:
        print(f"No route for {label}, skipping.")
        continue

    dest = DEST_PROJECTS[route_key]

    # --- Extract with Retab
    extraction = client.projects.extract(
        project_id=dest["project_id"],
        iteration_id=dest["iteration_id"],
        document=str(doc),
    )

    print(f"Extraction result → {extraction}")
# Out:
# Processing: medical_bill_sample1.jpg
# Classifier → 'MEDICAL_BILL_UB04'
# Extraction result → RetabParsedChatCompletion(id='chatcmpl-C3j0Mx3ejRRZAf06kVwFnlMCvWLjx', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"provider_name": "KISHWAUKEE COMMUNITY HOSP", "provider_address": "ONE KISH HOSPITAL DR, PO BOX 846, DEKALB, IL 601154939", "provider_phone": "8157561521", "bill_type": "other", "bill_number": "V0002014", "statement_period_from": "2010-04-05", "statement_period_through": "2010-04-05", "patient_name": "TEST, FRIDAY", "patient_address": "1600 PENNSYLVANIA AVENUE, DEKALB, IL 60115", "patient_dob": "1953-03-26", "patient_sex": "M", "admission_date": "2010-04-05", "discharge_date": "2010-04-05", "payer_details": [{"payer_name": "AETNA", "group_name": "", "group_number": "", "health_plan_id": ""}], "diagnosis_codes": ["7062"], "service_lines": [{"rev_code": "0300", "description": "LABORATORY GENERAL", "hcpcs_code": "36415", "service_date": "2010-04-05", "service_units": 2, "total_charges": 4140, "non_covered_charges": 0}, {"rev_code": "0300", "description": "LABORATORY GENERAL", "hcpcs_code": "82550", "service_date": "2010-04-05", "service_units": 1, "total_charges": 6660, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "80053", "service_date": "2010-04-05", "service_units": 1, "total_charges": 20700, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "80061", "service_date": "2010-04-05", "service_units": 1, "total_charges": 11500, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "80162", "service_date": "2010-04-05", "service_units": 1, "total_charges": 13680, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "80164", "service_date": "2010-04-05", "service_units": 1, "total_charges": 18720, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "80178", "service_date": "2010-04-05", "service_units": 1, "total_charges": 6030, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "80185", "service_date": "2010-04-05", "service_units": 1, "total_charges": 18720, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "80198", "service_date": "2010-04-05", "service_units": 1, "total_charges": 10800, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "82043", "service_date": "2010-04-05", "service_units": 1, "total_charges": 7710, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "82553", "service_date": "2010-04-05", "service_units": 1, "total_charges": 30020, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "82728", "service_date": "2010-04-05", "service_units": 1, "total_charges": 13050, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "83540", "service_date": "2010-04-05", "service_units": 1, "total_charges": 8820, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "83550", "service_date": "2010-04-05", "service_units": 1, "total_charges": 8820, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "83605", "service_date": "2010-04-05", "service_units": 1, "total_charges": 6480, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "83690", "service_date": "2010-04-05", "service_units": 1, "total_charges": 9430, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "84156", "service_date": "2010-04-05", "service_units": 1, "total_charges": 5310, "non_covered_charges": 0}, {"rev_code": "0301", "description": "LAB CHEMISTRY", "hcpcs_code": "84436", "service_date": "2010-04-05", "service_units": 1, "total_ ...
#
# Processing: medical_bill_sample3 (picture).pdf
# Classifier → 'OTHER'
# No route for OTHER, skipping.
#
# Processing: loss_runs_sample2.jpg
# Classifier → 'LOSS_RUN'
# Extraction result → RetabParsedChatCompletion(id='chatcmpl-C3j7ojeFSyZeajazw9F8IWEiIRnVW', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"report_date": "2021-04-26", "policy_holder": "TEST COMPANY, INC.", "policy_effective_period": {"start_date": "2016-04-26", "end_date": "2021-04-26"}, "claims": [{"claim_number": "E6L1234", "status": "closed", "incident_date": "2016-07-22", "report_date": "2016-07-27", "close_date": "2016-11-28", "claimant_name": "TES (TEST SERVICES COOP)", "loss_description": "IV R/E OV AND PUSHED OV2 INTO OV AT A STOP LIGHT", "line_of_insurance": "AL - AUTOMOBILE", "financials": {"total_paid": 0, "total_incurred": 0, "indemnity_paid": 0, "medical_paid": 0, "vocational_paid": 0, "legal_paid": 0, "expense_paid": 0, "indemnity_reserve": 0, "medical_reserve": 0, "vocational_reserve": 0, "legal_reserve": 0, "expense_reserve": 0}, "body_part": "", "claim_type": "", "department": "", "diagnosis": "", "insured_name": ""}, {"claim_number": "E8B1234", "claimant_name": "SENSIBLE DEPARTMENT", "status": "closed", "incident_date": "2017-03-06", "report_date": "2017-03-21", "close_date": "2021-02-17", "loss_description": "IV REAR ENDED OV ON 710 FREEWAY", "line_of_insurance": "AL - AUTOMOBILE", "financials": {"total_paid": 155106.55, "total_incurred": 155107, "indemnity_paid": 100000, "medical_paid": 0, "vocational_paid": 0, "legal_paid": 0, "expense_paid": 55106.55, "indemnity_reserve": 0, "medical_reserve": 0, "vocational_reserve": 0, "legal_reserve": 0, "expense_reserve": 0}, "body_part": "", "claim_type": "", "department": "", "diagnosis": "", "insured_name": ""}, {"claim_number": "E8B2345", "claimant_name": "SENSIBLE BAKERY", "status": "closed", "incident_date": "2017-01-06", "report_date": "2017-01-09", "close_date": "2017-03-31", "loss_description": "OV WAS WB ON HWY AT INTERSECTION. IV R/E OV.", "line_of_insurance": "AL - AUTOMOBILE", "financials": {"total_paid": 3145.83, "total_incurred": 3146, "indemnity_paid": 3145.83, "medical_paid": 0, "vocational_paid": 0, "legal_paid": 0, "expense_paid": 0, "indemnity_reserve": 0, "medical_reserve": 0, "vocational_reserve": 0, "legal_reserve": 0, "expense_reserve": 0}, "body_part": "", "claim_type": "", "department": "", "diagnosis": "", "insured_name": ""}, {"claim_number": "E9R1234", "claimant_name": "JOHN SMITH", "status": "closed", "incident_date": "2017-05-31", "report_date": "2017-06-15", "close_date": "2017-08-16", "loss_description": "IV WAS STOPPED AT STOP SIGN WHEN HE WAS HIT FROM BEHIND BY OV GOING APPROX 25MPH.", "line_of_insurance": "AL - AUTOMOBILE", "financials": {"total_paid": 2667.98, "total_incurred": 2668, "indemnity_paid": 2667.98, "medical_paid": 0, "vocational_paid": 0, "legal_paid": 0, "expense_paid": 0, "indemnity_reserve": 0, "medical_reserve": 0, "vocational_reserve": 0, "legal_reserve": 0, "expense_reserve": 0}, "body_part": "", "claim_type": "", "department": "", "diagnosis": "", "insured_name": ""}, {"claim_number": "E9R2345", "claimant_name": "JANE DOE", "status": "closed", "incident_date": "2017-06-18", "report_date": "2017-06-21", "close_date": "2017-07-06", "loss_description": "IV WAS TRYING TO PARK WHEN IV DRIVER ACCIDENTLY ACCELLERATED IV RESULTING IN IV R/E OV THAT WAS PARKED UNOCCUPIED ON THE STREET.", "line_of_insurance": "AL - AUTOMOBILE", "financials": {"total_paid": 3505.35, "total_incurred": 3505, "indemnity_paid": 3505.35, "medical_paid": 0, "vocational_paid": 0, "legal_paid": 0, "expense_paid": 0, "indemnity_reserve": 0, "medical_reserve": 0, "vocational_reserve": 0, "legal_reserve": 0, "expense_reserve": 0}, "body_part": "", "claim_type": "", "department": "", "diagnosis": "", "insured_name": ""}, {"claim_number": "E9R3456", "claimant_name": "UNKNOWN UNKNOWN", "status": "closed", "incident_date": "2017-06-27", "report_date": "2017-09-18", "close_date": "2018-11-27", "loss_description": "CALLER STATES IV WAS HIT BY OV.", "line_of_insurance": "AL - AUTOMOBILE" ...
#
# Processing: demand_letter_sample2.pdf
# Classifier → 'DEMAND_LETTER'
# Extraction result → RetabParsedChatCompletion(id='chatcmpl-C3j3MswECtFdcBhbag2v4YFdrFwb3', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"sender": {"name": "Wanda Shore", "address": "21566 Riverside Drive\\nLos Angeles, CA 00000", "contact": "", "representative": {"name": "", "role": ""}}, "account_reference": "93-1033 BS", "recipient": {"name": "Roger de la Rue", "address": "Twentieth Century Insurance Adjuster\\n6400 Century Boulevard\\nLos Angeles, CA 00000"}, "subject": "Your Insured, Broadmart Stores", "debt_details": {"amount": 120000, "currency": "USD", "penalties_included": false, "amount_text": "one hundred twenty thousand dollars", "reason": "Personal injury compensation for a shattered right arm after a slip and fall accident at the West Hollywood Broadmart store, requiring surgery, months of rehabilitation, and resulting in permanent loss of some use of the arm.", "as_of_date": "", "invoice_numbers": []}, "final_demand": false, "legal_warning": true, "sender_signature": "Wanda Shore", "days_overdue": 0, "payment_deadline_days": 0, "vacate_deadline_days": 0, "legal_action_description": "If this matter is not settled before January, I will be forced to file a lawsuit against Broadmart stores to protect my legal interests.", "client": {"name": "", "role": ""}, "letter_date": ""}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'sender': {'name': 'Wanda Shore', 'address': '21566 Riverside Drive\nLos Angeles, CA 00000', 'contact': '', 'representative': {'name': '', 'role': ''}}, 'account_reference': '93-1033 BS', 'recipient': {'name': 'Roger de la Rue', 'address': 'Twentieth Century Insurance Adjuster\n6400 Century Boulevard\nLos Angeles, CA 00000'}, 'subject': 'Your Insured, Broadmart Stores', 'debt_details': {'amount': 120000, 'currency': 'USD', 'penalties_included': False, 'amount_text': 'one hundred twenty thousand dollars', 'reason': 'Personal injury compensation for a shattered right arm after a slip and fall accident at the West Hollywood Broadmart store, requiring surgery, months of rehabilitation, and resulting in permanent loss of some use of the arm.', 'as_of_date': '', 'invoice_numbers': []}, 'final_demand': False, 'legal_warning': True, 'sender_signature': 'Wanda Shore', 'days_overdue': 0, 'payment_deadline_days': 0, 'vacate_deadline_days': 0, 'legal_action_description': 'If this matter is not settled before January, I will be forced to file a lawsuit against Broadmart stores to protect my legal interests.', 'client': {'name': '', 'role': ''}, 'letter_date': ''}), field_locations=None, key_mapping=None), RetabParsedChoice(finish_reason='stop', index=1, logprobs=None, message=ParsedChatCompletionMessage(content='{"reasoning___letter_date": "The letter date is explicitly stated as \'September 15, 20xx\' in the address block. The year is incomplete (\'20xx\'), so per instructions, the cell is left empty.", "letter_date": "September 15, 20xx", "sender": {"name": "Wanda Shore", "address": "21566 Riverside Drive\\nLos Angeles, CA 00000", "reasoning___contact": "No phone number or email address for the sender is provided anywhere in the document. Only the postal address is given.", "contact": "", "representative": {"name": "", "role": ""}}, "recipient": {"name": "Roger de la Rue", "address": "Twentieth Century Insurance Adjuster\\n6400 Century Boulevard\\nLos Angeles, CA 00000"}, "client": {"name": "", "role": ""}, "subject": "Your Insured, Broadmart Stores", "account_reference": "93-1033 BS", "debt_details": {"amount": 120000, "currency": "USD", "reasoning___amount_text": "The amount \'$120,000\' is stated as \'I demand $120,000 as compensation.\' To translate this into words: \'one hundred twenty thousand dollars.\'", "amount_text": "one hundred twenty thousand dollars", "as_of_date": "", "reason": "Compensation for personal injury (shattered right arm) from slip and fall accident  ...
#
# Processing: invoice_sample3.png
# Classifier → 'CONTRACTOR_INVOICE'
# Extraction result → RetabParsedChatCompletion(id='CTKkaKe-A_GP28oP0rHV2Q8', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"vendor_name": "Your Company Inc.", "vendor_address": "1234 Company St, Company Town, ST 12345", "client_name": "Customer Name", "invoice_number": "0000007", "invoice_date": "2023-10-02", "due_date": "2023-10-16", "client_address": "1234 Customer St, Customer Town, ST 12345", "currency": "USD", "line_items": [{"description": "Front bumper replacement", "quantity": 1, "unit_price": 11.5, "amount": 60, "unit": ""}, {"description": "Passenger side door repaint", "quantity": 1, "unit_price": 150, "amount": 150, "unit": ""}, {"description": "New tires", "quantity": 4, "unit_price": 100, "amount": 400, "unit": ""}, {"description": "Hours of labor (@$60/hr)", "quantity": 3, "unit": "Hours", "unit_price": 60, "amount": 180}], "subtotal": 980, "tax": 230, "total": 1029, "payment_terms": "Payment is due in 14 days", "amount_paid": 0, "balance_due": 1029, "notes": "Please make checks payable to: Your Company Inc.", "client_contact": "", "job_reference": "", "vendor_contact": ""}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'vendor_name': 'Your Company Inc.', 'vendor_address': '1234 Company St, Company Town, ST 12345', 'client_name': 'Customer Name', 'invoice_number': '0000007', 'invoice_date': '2023-10-02', 'due_date': '2023-10-16', 'client_address': '1234 Customer St, Customer Town, ST 12345', 'currency': 'USD', 'line_items': [{'description': 'Front bumper replacement', 'quantity': 1, 'unit_price': 11.5, 'amount': 60, 'unit': ''}, {'description': 'Passenger side door repaint', 'quantity': 1, 'unit_price': 150, 'amount': 150, 'unit': ''}, {'description': 'New tires', 'quantity': 4, 'unit_price': 100, 'amount': 400, 'unit': ''}, {'description': 'Hours of labor (@$60/hr)', 'quantity': 3, 'unit': 'Hours', 'unit_price': 60, 'amount': 180}], 'subtotal': 980, 'tax': 230, 'total': 1029, 'payment_terms': 'Payment is due in 14 days', 'amount_paid': 0, 'balance_due': 1029, 'notes': 'Please make checks payable to: Your Company Inc.', 'client_contact': '', 'job_reference': '', 'vendor_contact': ''}), field_locations=None, key_mapping=None), RetabParsedChoice(finish_reason='stop', index=1, logprobs=None, message=ParsedChatCompletionMessage(content='{"vendor_name": "Your Company Inc.", "vendor_address": "1234 Company St, Company Town, ST 12345", "vendor_contact": "", "client_name": "Customer Name", "client_address": "1234 Customer St, Customer Town, ST 12345", "client_contact": "", "invoice_number": "0000007", "invoice_date": "2023-10-02", "due_date": "2023-10-16", "job_reference": "", "line_items": [{"description": "Front bumper replacement", "quantity": 1, "unit": "", "unit_price": 11.5, "amount": 60}, {"description": "Passenger side door repaint", "quantity": 1, "unit": "", "unit_price": 150, "amount": 150}, {"description": "New tires", "quantity": 4, "unit": "", "unit_price": 100, "amount": 400}, {"description": "Hours of labor (@$60/hr)", "quantity": 3, "unit": "Hours", "unit_price": 60, "amount": 180}], "subtotal": 980, "tax": 230, "total": 1029, "currency": "USD", "payment_terms": "Payment is due in 14 days", "amount_paid": 0, "balance_due": 1029, "notes": "Please make checks payable to: Your Company Inc."}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'vendor_name': 'Your Company Inc.', 'vendor_address': '1234 Company St, Company Town, ST 12345', 'vendor_contact': '', 'client_name': 'Customer Name', 'client_address': '1234 Customer St, Customer Town, ST 12345', 'client_contact': '', 'invoice_number': '0000007', 'invoice_date': '2023-10-02', 'due_date': '2023-10-16', 'job_reference': '', 'line_items': [{'description': 'Front bumper replacement', 'quantity': 1, 'unit': '', 'unit_price': 11.5, 'amount': 60}, {'description': 'Passe ...
#
# Processing: invoice_sample4 (bad quality).jpg
# Classifier → 'CONTRACTOR_INVOICE'
# Extraction result → RetabParsedChatCompletion(id='chatcmpl-C3gvBNFnx2Wi2ZtPDyvCmg7jCor7W', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"vendor_name": "ABC Painting & Renovators", "vendor_address": "1233 Springvale Road, Glen Waverly, Victoria 3456, Australia", "vendor_contact": "Tel : 03-7654-1234, Fax : 03-7654-1235, Email : sales@abc-painting.com", "client_name": "As Interior Design Co", "client_address": "P.O. Box 8000\\nTamworth\\n2340\\nAustralia", "client_contact": "Attention : Alan\\nTel : 0406533590", "invoice_number": "IN1008", "invoice_date": "2013-04-30", "due_date": "2013-04-30", "job_reference": "JB1000", "line_items": [{"unit": "L", "description": "4 Seasons Gloss White Exterior Paint", "quantity": 10, "unit_price": 20, "amount": 200}, {"unit": "L", "description": "4 Seasons Low Sheen White Exterior Paint", "quantity": 10, "unit_price": 15, "amount": 150}, {"unit": "L", "description": "Extra Bright Gloss Enamel Interior Paint", "quantity": 10, "unit_price": 20, "amount": 200}, {"unit": "L", "description": "High Gloss Enamel Interior Paint", "quantity": 10, "unit_price": 25, "amount": 250}, {"unit": "L", "description": "White Precoat Interior Paint", "quantity": 10, "unit_price": 15, "amount": 150}, {"unit": "L", "description": "Acrylic Sealer Undercoat Interior Paint", "quantity": 10, "unit_price": 10, "amount": 100}], "currency": "AUD", "subtotal": 1050, "tax": 105, "total": 1155, "payment_terms": "Credit Terms Cash", "amount_paid": 0, "balance_due": 1155, "notes": ""}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'vendor_name': 'ABC Painting & Renovators', 'vendor_address': '1233 Springvale Road, Glen Waverly, Victoria 3456, Australia', 'vendor_contact': 'Tel : 03-7654-1234, Fax : 03-7654-1235, Email : sales@abc-painting.com', 'client_name': 'As Interior Design Co', 'client_address': 'P.O. Box 8000\nTamworth\n2340\nAustralia', 'client_contact': 'Attention : Alan\nTel : 0406533590', 'invoice_number': 'IN1008', 'invoice_date': '2013-04-30', 'due_date': '2013-04-30', 'job_reference': 'JB1000', 'line_items': [{'unit': 'L', 'description': '4 Seasons Gloss White Exterior Paint', 'quantity': 10, 'unit_price': 20, 'amount': 200}, {'unit': 'L', 'description': '4 Seasons Low Sheen White Exterior Paint', 'quantity': 10, 'unit_price': 15, 'amount': 150}, {'unit': 'L', 'description': 'Extra Bright Gloss Enamel Interior Paint', 'quantity': 10, 'unit_price': 20, 'amount': 200}, {'unit': 'L', 'description': 'High Gloss Enamel Interior Paint', 'quantity': 10, 'unit_price': 25, 'amount': 250}, {'unit': 'L', 'description': 'White Precoat Interior Paint', 'quantity': 10, 'unit_price': 15, 'amount': 150}, {'unit': 'L', 'description': 'Acrylic Sealer Undercoat Interior Paint', 'quantity': 10, 'unit_price': 10, 'amount': 100}], 'currency': 'AUD', 'subtotal': 1050, 'tax': 105, 'total': 1155, 'payment_terms': 'Credit Terms Cash', 'amount_paid': 0, 'balance_due': 1155, 'notes': ''}), field_locations=None, key_mapping=None), RetabParsedChoice(finish_reason='stop', index=1, logprobs=None, message=ParsedChatCompletionMessage(content='{"vendor_name": "ABC Painting & Renovators", "vendor_address": "1233 Springvale Road, Glen Waverly, Victoria 3456, Australia", "vendor_contact": "Tel : 03-7654-1234, Fax : 03-7654-1235, Email : sales@abc-painting.com", "client_name": "As Interior Design Co", "client_address": "P.O. Box 8000\\nTamworth\\n2340\\nAustralia", "client_contact": "Attention : Alan\\nTel : 0406533590", "invoice_number": "IN1008", "invoice_date": "2013-04-30", "due_date": "2013-04-30", "job_reference": "JB1000", "line_items": [{"description": "4 Seasons Gloss White Exterior Paint", "quantity": 10, "unit": "L", "unit_price": 20, "amount": 200}, {"description": "4 Seasons Low Sheen White Exterior Paint", "quantity": 10, "unit": "L", "unit_price": 15, "amount": 150}, {"description": "Extra Bright Gloss  ...
#
# Processing: repair_estimates_sample1.pdf
# Classifier → 'REPAIR_ESTIMATE'
# Extraction result → RetabParsedChatCompletion(id='chatcmpl-C3j6cWIsWjYmFVjaX4jaWyE4Twzlw', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"workfile_id": "2372f95f", "estimate_date": "2024-01-27T16:46:50", "owner": {"name": "DOE, JOHN", "phone": "(999) 999-9999 Day", "address": ""}, "insured": "DOE, JOHN", "claim_number": "BSOC", "date_of_loss": "2023-12-05T00:00:00", "inspection_location": "Other", "point_of_impact": "01 Right Front", "vehicle": {"year": 2022, "make": "FORD", "model": "Expedition", "trim": "XLT", "vin": "1FMJU1HT1MEA88888", "production_date": "2021-01", "license": "-", "state": "GA", "odometer": 27176, "condition": "Good", "body_style": "4D UTV", "exterior_color": "BLACK", "engine": "6-3.5L Turbocharged Gasoline Port/Direct Injection", "options": ["Intermittent Wipers", "AM Radio", "Lane Departure Warning", "Automatic Transmission", "Tilt Wheel", "FM Radio", "Cruise Control", "Stereo", "Cloth Seats", "Power Steering", "Rear Defogger", "Search/Seek", "Reclining/Lounge Seats", "Power Brakes", "Keyless Entry", "Auxiliary Audio Connection", "Power Third Seat", "Power Windows", "Alarm", "Satellite Radio", "Power Locks", "Message Center", "Aluminum/Alloy Wheels", "Power Mirrors", "Steering Wheel Touch Controls", "Drivers Side Air Bag", "Heated Mirrors", "Rear Window Wiper", "Passenger Air Bag", "Clear Coat Paint", "Power Driver Seat", "Telescopic Wheel", "Anti-Lock Brakes (4)", "Climate Control", "4 Wheel Disc Brakes", "Fog Lamps", "Dual Mirrors", "Dual Air Condition", "Traction Control", "Privacy Glass", "Backup Camera", "Stability Control", "Rear Step Bumper", "Console/Storage", "Parking Sensors", "Front Side Impact Air Bags", "Trailer Hitch", "Overhead Console", "Remote Starter", "Head/Curtain Air Bags", "Trailering Package", "Home Link", "Hands Free Device", "Running Boards/Side Steps", "Air Conditioning", "Blind Spot Detection"], "drive_train": "", "interior_color": ""}, "repair_lines": [{"operation": "replace", "part_number": "JL1Z17D957FPTM", "line_number": 3, "description": "A/M CAPA Upper cover w/park sensors w/o auto park", "quantity": 1, "extended_price": 593, "labor_hours": 3.8, "paint_hours": 2.3, "section": "FRONT BUMPER & GRILLE", "labor_type": "", "notes": ""}, {"operation": "add", "line_number": 4, "description": "Add for Clear Coat", "quantity": 0, "extended_price": 0, "labor_hours": 0, "paint_hours": 0.9, "section": "FRONT BUMPER & GRILLE", "labor_type": "", "notes": "", "part_number": ""}, {"operation": "replace", "line_number": 6, "labor_type": "mechanical", "description": "Add for park sensor", "quantity": 1, "extended_price": 0, "labor_hours": 0.8, "paint_hours": 0, "section": "FRONT BUMPER & GRILLE", "notes": "", "part_number": ""}, {"operation": "replace", "part_number": "KL1Z17D957AAPTM", "line_number": 7, "description": "A/M CAPA Lower cover w/front park sensors", "quantity": 1, "extended_price": 311, "labor_hours": 0, "paint_hours": 0, "section": "FRONT BUMPER & GRILLE", "labor_type": "", "notes": ""}, {"operation": "replace", "part_number": "LL1Z8200BB", "line_number": 8, "description": "A/M CAPA Grille assy magnetic chrome # 2 w/o front camera", "quantity": 1, "extended_price": 1397, "labor_hours": 2.4, "paint_hours": 0, "section": "FRONT BUMPER & GRILLE", "labor_type": "", "notes": ""}, {"operation": "replace", "part_number": "JL1Z17K945AB", "line_number": 9, "description": "A/M CAPA Bumper grille w/o adaptive cruise", "quantity": 1, "extended_price": 206, "labor_hours": 0, "paint_hours": 0, "section": "FRONT BUMPER & GRILLE", "labor_type": "", "notes": ""}, {"operation": "replace", "part_number": "JL1Z15A246BA", "line_number": 10, "description": "RT Fog lamp bezel w/LED fog lamps", "quantity": 1, "extended_price": 71.53, "labor_hours": 0, "paint_hours": 0, "section": "FRONT BUMPER & GRILLE", "labor_type": "", "notes": ""}, {"operation": "replace", "part_number": "JL1Z15A245AE", "line_number": 11, "description": "R ...
#
# Processing: demand_letter_sample1 (picture).webp
# Classifier → 'DEMAND_LETTER'
# Extraction result → RetabParsedChatCompletion(id='ZjKkaPy5GKOOxN8P7-2goQ4', choices=[RetabParsedChoice(finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage(content='{"letter_date": "2009-06-15", "account_reference": "WFM 01002506", "final_demand": false, "legal_warning": true, "sender_signature": "L. Noblitt", "sender": {"name": "Stores Protective Association", "address": "Post Office Box 2219 Simi Valley, California 93062", "contact": "Tel (805)630-1015 Fax (805)526-5490", "representative": {"name": "L. Noblitt", "role": "Unit Supervisor"}}, "recipient": {"name": "Ms. Elle Ko", "address": "32440 Lake Temescal Fremont, CA 94555"}, "client": {"name": "Whole Foods Market", "role": "Client"}, "subject": "Ms. Elle Ko", "debt_details": {"amount": 500.0, "currency": "USD", "amount_text": "Five Hundred", "as_of_date": "2009-06-15", "penalties_included": false, "reason": "Incident which occurred at their San Francisco store on 4/06/2008.", "invoice_numbers": []}, "days_overdue": 0, "payment_deadline_days": 10, "vacate_deadline_days": 0, "legal_action_description": "Our client is considering further action in this matter. One option is to pursue this matter in the Small Claims division of Municipal Court. ... does not preclude possible criminal action taken against you."}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, parsed={'letter_date': '2009-06-15', 'account_reference': 'WFM 01002506', 'final_demand': False, 'legal_warning': True, 'sender_signature': 'L. Noblitt', 'sender': {'name': 'Stores Protective Association', 'address': 'Post Office Box 2219 Simi Valley, California 93062', 'contact': 'Tel (805)630-1015 Fax (805)526-5490', 'representative': {'name': 'L. Noblitt', 'role': 'Unit Supervisor'}}, 'recipient': {'name': 'Ms. Elle Ko', 'address': '32440 Lake Temescal Fremont, CA 94555'}, 'client': {'name': 'Whole Foods Market', 'role': 'Client'}, 'subject': 'Ms. Elle Ko', 'debt_details': {'amount': 500.0, 'currency': 'USD', 'amount_text': 'Five Hundred', 'as_of_date': '2009-06-15', 'penalties_included': False, 'reason': 'Incident which occurred at their San Francisco store on 4/06/2008.', 'invoice_numbers': []}, 'days_overdue': 0, 'payment_deadline_days': 10, 'vacate_deadline_days': 0, 'legal_action_description': 'Our client is considering further action in this matter. One option is to pursue this matter in the Small Claims division of Municipal Court. ... does not preclude possible criminal action taken against you.'}), field_locations=None, key_mapping=None), RetabParsedChoice(finish_reason='stop', index=1, logprobs=None, message=ParsedChatCompletionMessage(content='{"reasoning___letter_date": "The letter date \'June 15, 2009\' is fully visible and complete at the top right of the document.", "letter_date": "2009-06-15", "sender": {"name": "Stores Protective Association", "address": "Post Office Box 2219 Simi Valley, California 93062", "reasoning___contact": "The contact details including telephone and fax numbers are fully visible at the bottom of the letter.", "contact": "Tel (805)630-1015 Fax (805)526-5490", "representative": {"name": "L. Noblitt", "role": "Unit Supervisor"}}, "recipient": {"name": "Ms. Elle Ko", "address": "32440 Lake Temescal Fremont, CA 94555"}, "client": {"name": "Whole Foods Market", "role": "Client"}, "subject": "Ms. Elle Ko", "account_reference": "WFM 01002506", "debt_details": {"amount": 500.0, "currency": "USD", "reasoning___amount_text": "The amount is written as a number \'$500.00\' in the document. I have translated this number into words.", "amount_text": "Five Hundred", "as_of_date": "2009-06-15", "reason": "Regarding the incident which occurred at their San Francisco store on 4/06/2008.", "invoice_numbers": [], "penalties_included": false}, "days_overdue": 0, "final_demand": false, "payment_deadline_days": 10, "vacate_deadline_days": 0, "legal_warning": true, "legal_action_description": "Our client is considering f ...

# %%
# PRINT THE EXTRACTION RESULT IN A NICE JSON FORMAT

import json

parsed_data = json.loads(extraction.choices[0].message.content)
formatted_json = json.dumps(parsed_data, indent=2, ensure_ascii=False)

print(formatted_json)
# Out:
# {
#   "letter_date": "2009-06-15",
#   "account_reference": "WFM 01002506",
#   "final_demand": false,
#   "legal_warning": true,
#   "sender_signature": "L. Noblitt",
#   "sender": {
#     "name": "Stores Protective Association",
#     "address": "Post Office Box 2219 Simi Valley, California 93062",
#     "contact": "Tel (805)630-1015 Fax (805)526-5490",
#     "representative": {
#       "name": "L. Noblitt",
#       "role": "Unit Supervisor"
#     }
#   },
#   "recipient": {
#     "name": "Ms. Elle Ko",
#     "address": "32440 Lake Temescal Fremont, CA 94555"
#   },
#   "client": {
#     "name": "Whole Foods Market",
#     "role": "Client"
#   },
#   "subject": "Ms. Elle Ko",
#   "debt_details": {
#     "amount": 500.0,
#     "currency": "USD",
#     "amount_text": "Five Hundred",
#     "as_of_date": "2009-06-15",
#     "penalties_included": false,
#     "reason": "Incident which occurred at their San Francisco store on 4/06/2008.",
#     "invoice_numbers": []
#   },
#   "days_overdue": 0,
#   "payment_deadline_days": 10,
#   "vacate_deadline_days": 0,
#   "legal_action_description": "Our client is considering further action in this matter. One option is to pursue this matter in the Small Claims division of Municipal Court. ... does not preclude possible criminal action taken against you."
# }
